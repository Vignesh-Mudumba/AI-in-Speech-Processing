# %%
#MUDUMBA HANUMAT KRISHNA VIGNESH
#BL.EN.U4AIE21082

# %%
#Q1
import librosa 
import numpy as np
import matplotlib.pyplot as plt
y, r = librosa.load("answer.wav")
Y = np.fft.fft(y)
amplitude = np.abs(Y)
plt.figure(figsize=(8, 4))
plt.plot(amplitude)
plt.title('Amplitude Spectrum of Speech Signal')
plt.xlabel('Frequency (bins)')
plt.ylabel('Amplitude')
plt.show()

# %%
## Q2
import numpy as np
import matplotlib.pyplot as plt

signal, sample_rate = librosa.load("answer.wav")  
# Apply FFT
fft_result = np.fft.fft(signal)

ifft_result = np.fft.ifft(fft_result[:len(fft_result)//2])

reconstructed_signal = np.real(ifft_result)

plt.plot(signal, label="Original Signal")
plt.plot(reconstructed_signal, label="Reconstructed Signal")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.legend()
plt.title("Original vs. Reconstructed Speech Signal")
plt.show()

# %%
#Q4
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft
sr=22500
window_duration = 0.02
window_samples = int(window_duration * sr)
windowed_signal = y[:window_samples]

X = fft(windowed_signal)

n_oneside = window_samples // 2
frequencies = np.arange(n_oneside) * (sr / window_samples)
spectrum = np.abs(X[:n_oneside])

plt.figure(figsize=(10, 6))
plt.plot(frequencies, spectrum, 'b')
plt.xlabel('Frequency (Hz)')
plt.ylabel('FFT Amplitude ')
plt.title('Frequency Spectrum of Speech Signal')
plt.grid(True)
plt.show()

# %%
#Q5
import seaborn as sns
y, sr = librosa.load('answer.wav')
librosa.display.waveshow(y, sr=sr)
plt.title('Speech Signal')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.show()
window_length_sec = 0.02
window_length = int(window_length_sec * sr)
num_windows = len(y) // window_length
freq_matrix = np.zeros((num_windows, window_length // 2 + 1))
for i in range(num_windows):
    window = y[i * window_length: (i + 1) * window_length]
    fft_result = np.fft.rfft(window)
    freq_matrix[i, :] = np.abs(fft_result)

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(freq_matrix.T, cmap='viridis', xticklabels=10)
plt.title('Frequency Components of Speech Signal')
plt.xlabel('Window Index')
plt.ylabel('Frequency Bin')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       2 import seaborn as sns
#       3 y, sr = librosa.load('answer.wav')
# ----> 4 librosa.display.waveshow(y, sr=sr)
#       5 plt.title('Speech Signal')
#       6 plt.xlabel('Time')
#
# File C:\Python310\lib\site-packages\librosa\display.py:2042, in waveshow(y, sr, max_points, axis, offset, marker, where, label, transpose, ax, x_axis, **kwargs)
#    2032 axis = rename_kw(
#    2033     old_name="x_axis",
#    2034     old_value=x_axis,
#    (...)
#    2038     version_removed="1.0",
#    2039 )
#    2041 if "color" not in kwargs:
# -> 2042     kwargs.setdefault("color", next(axes._get_lines.prop_cycler)["color"])
#    2044 # Reduce by envelope calculation
#    2045 # this choice of hop ensures that the envelope has at most max_points values
#    2046 hop_length = max(1, y.shape[-1] // max_points)
#
# AttributeError: '_process_plot_var_args' object has no attribute 'prop_cycler'
